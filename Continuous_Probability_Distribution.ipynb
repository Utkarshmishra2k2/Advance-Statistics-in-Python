# %% [markdown]
# <a href="https://colab.research.google.com/github/Utkarshmishra2k2/Advance-Statistics-in-Python/blob/main/Continuous_Probability_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy import random
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# #Normal Distribution

# %% [markdown]
# Normal distributions are important in statistics and are often used in the natural and social sciences to represent real-valued random variables whose distributions are not known.Their importance is partly due to the central limit theorem.

# %% [markdown]
# A random variable X is said to have a normal distribution with parameter μ (mean) & σ^2(variance) if it's pdf is given by,
# ```
# f(X = x) = (1/√(2πσ2)) (e[-(x-μ)^2]/2σ^2)  ; -∞ < x, μ < ∞ ;0 < σ
#      = 0 ;Otherwise
# ```

# %%
from scipy.stats import norm

# %% [markdown]
# Generating the Sample of Size 1000

# %%
norm.rvs(size=100)
# Out:
# array([ 0.52858106,  0.06097411,  0.4110561 , -0.42035671,  0.70334293,
#        -0.20670489,  1.26103373, -1.15304619,  0.34718968, -0.23896235,
#         0.36240248,  0.60492807, -0.10379548,  0.98073334, -0.30515757,
#         0.89624578,  1.04831018, -0.41452356,  0.74154353,  0.36481462,
#        -0.68196162, -1.65621967,  1.05082032,  0.02877973,  0.79370956,
#        -0.60836706,  0.06512396, -0.58225423, -1.09457876,  1.10039237,
#        -0.18140338, -1.34340541, -0.45371025,  0.13467983, -0.1666208 ,
#         2.23570009, -0.16835703,  2.41787682, -0.78067373,  0.1684722 ,
#         0.52709143,  0.66057807, -0.17941945,  0.58833191, -0.48990654,
#         0.14534017,  1.40310809, -1.58020465,  1.43417303, -0.58364526,
#        -1.77925805,  0.01177902, -0.05838776,  1.77974556,  0.91495022,
#        -0.50757123,  1.57410283, -1.3667807 ,  0.42551607,  1.63744135,
#         1.59935673, -0.13904489,  1.94727075,  0.70763867, -0.52218905,
# ...

# %% [markdown]
# Find Probability using Probability Mass Function

# %%
norm.pdf(x = 20 , loc  = 25 , scale = 5 )
# Out:
# 0.04839414490382867

# %% [markdown]
# Find Cumulative Distribution Function

# %%
norm.cdf(x = 20 , loc  = 25 , scale = 5 )
# Out:
# 0.15865525393145707

# %% [markdown]
# Moments of Distibution

# %%
m , v , s , k = norm.stats(loc  = 25 , scale = 5, moments='mvsk')
print("Mean = {} , Variance = {} , Skewness = {} , Kurtosis = {} .".format(m,v,s,k))
# Out:
# Mean = 25.0 , Variance = 25.0 , Skewness = 0.0 , Kurtosis = 0.0 .

# %% [markdown]
# Graph Of Distribution

# %%
plt.figure(figsize=(25,25))
data_01 =norm.rvs(size=100)
plt.hist(data_01, density=True, edgecolor='black')
plt.show()

# %% [markdown]
# #Continous Uniform Distribution

# %% [markdown]
# Uniform distributions are probability distributions with equally likely outcomes.

# %% [markdown]
# A random variable is said have continous uniform distribution over the range (low - high) if its pdf is given b) if it's pdf is given by,
# ```
# f( X = x ) = 1/( high - low ) ; low < x < high
#            = 0;Otherwisee
# ```

# %%
from scipy.stats import uniform

# %% [markdown]
# Generating the Sample of Size 1000

# %%
uniform.rvs(size=100)
# Out:
# array([8.08704481e-01, 8.57362710e-01, 1.93539328e-01, 1.13579234e-01,
#        8.67836801e-01, 7.55491937e-01, 1.30494389e-01, 6.80159583e-01,
#        2.74366037e-01, 9.57369636e-01, 9.46096853e-01, 1.41416471e-01,
#        9.83877747e-01, 5.59176423e-01, 2.27015512e-01, 1.03410978e-01,
#        1.21901789e-01, 5.48887663e-01, 9.58121314e-02, 5.93689087e-01,
#        5.63537828e-02, 8.77250334e-01, 7.40678361e-01, 9.27143229e-04,
#        2.96965530e-01, 8.83012895e-01, 6.62886184e-01, 6.80671544e-01,
#        6.14984856e-01, 3.61739388e-01, 7.33761133e-01, 7.03287537e-01,
#        9.23784793e-01, 1.66967492e-01, 8.17433750e-01, 1.63456964e-01,
#        4.84749085e-01, 6.50867608e-01, 7.66651372e-01, 6.90044923e-01,
#        7.21131491e-02, 9.12107781e-01, 7.18132908e-01, 1.58189848e-02,
#        3.05579788e-02, 9.09251932e-01, 7.53358671e-01, 3.01252718e-01,
#        7.44088121e-01, 6.10942928e-01, 9.52194472e-01, 7.06350903e-01,
# ...

# %% [markdown]
# Find Probability using Probability Mass Function

# %%
uniform.pdf(x = 47 , loc  = 25 , scale = 75 )
# Out:
# 0.013333333333333334

# %% [markdown]
# Find Cumulative Distribution Function

# %%
uniform.cdf(x = 47 , loc  = 25 , scale = 75 )
# Out:
# 0.29333333333333333

# %% [markdown]
# Moments of Distibution

# %%
m , v , s , k = uniform.stats(loc  = 25 , scale = 75, moments='mvsk')
print("Mean = {} , Variance = {} , Skewness = {} , Kurtosis = {} .".format(m,v,s,k))
# Out:
# Mean = 62.5 , Variance = 468.75 , Skewness = 0.0 , Kurtosis = -1.2 .

# %% [markdown]
# Graph Of Distribution

# %%
plt.figure(figsize=(25,25))
data_01 =uniform.rvs(size=100)
plt.hist(data_01, density=True, edgecolor='black')
plt.show()

# %% [markdown]
# #Gamma Distribution

# %% [markdown]
# The gamma distribution is a two-parameter family of continuous probability distributions.

# %% [markdown]
# A random variable X is said to have a gamma distribution with parameter λ>0,if its p.d.f is given by
#
# ```
# f(X = x) = (x^(λ−1)  * e^−x)/Γ(λ); 0 < y < ∞,λ>0
#          = 0, otherwise
# ```

# %%
from scipy.stats import gamma

# %% [markdown]
# Generating the Sample of Size 1000

# %%
gamma.rvs(1.69, size=100)
# Out:
# array([ 0.28463006,  2.18938044,  2.61892521,  1.55829253, 10.47280824,
#         0.95632981,  2.21152696,  3.22615886,  0.75597676,  3.39817094,
#         0.74995417,  1.93537952,  0.42088149,  0.90862131,  0.85949882,
#         1.10693634,  1.27571714,  0.78343986,  0.77078486,  3.43440838,
#         1.69349164,  2.22944651,  1.03139604,  0.88982582,  1.90363056,
#         2.72830014,  0.34320621,  1.35958058,  1.85472266,  1.56661242,
#         0.49561649,  1.47624205,  3.55376098,  2.72290263,  1.57194454,
#         1.7309533 ,  2.47548479,  0.81305325,  3.51043363,  0.22266701,
#         3.61805729,  2.24053538,  0.41677866,  4.05423884,  1.92162381,
#         0.54533583,  1.21247121,  0.98924607,  1.14279376,  2.16540086,
#         1.39066339,  1.83551049,  1.94782547,  1.21788237,  4.1643845 ,
#         1.05342225,  0.44368299,  1.09855461,  2.90482594,  0.43679136,
#         1.09896596,  1.5046977 ,  0.21121809,  2.8345464 ,  1.26189154,
# ...

# %% [markdown]
# Find Probability using Probability Mass Function

# %%
gamma.pdf(x=10 ,a = 1.99, loc = 2 ,scale = 0.2 )
# Out:
# 8.223415132283346e-16

# %% [markdown]
# Find Cumulative Distribution Function

# %%
gamma.cdf(x=10 ,a = 1.99, loc = 2 ,scale = 0.2 )
# Out:
# 0.9999999999999998

# %% [markdown]
# Moments of Distibution

# %%
m , v , s , k = gamma.stats(a = 1.99, loc = 2 ,scale = 0.2 , moments='mvsk')
print("Mean = {} , Variance = {} , Skewness = {} , Kurtosis = {} .".format(m,v,s,k))
# Out:
# Mean = 2.398 , Variance = 0.0796 , Skewness = 1.4177624100166717 , Kurtosis = 3.0150753768844223 .

# %% [markdown]
# Graph Of Distribution

# %%
plt.figure(figsize=(25,25))
data_01 = gamma.rvs(1.69, size=100)
plt.hist(data_01, density=True, edgecolor='black')
plt.show()

# %% [markdown]
# #Exponential Distribution

# %% [markdown]
# The exponential distribution or negative exponential distribution is the probability distribution of the time between events in a Poisson point process, i.e., a process in which events occur continuously and independently at a constant average rate. It is a particular case of the gamma distribution. It is the continuous analogue of the geometric distribution, and it has the key property of being memoryless. In addition to being used for the analysis of Poisson point processes it is found in various other contexts

# %% [markdown]
# A random variable X is said to have an exponential distribution with parameter λ>0 if its PDF is given by
#
# ```
# f( X = x ) = λe^(−λx) ; x>0
#      = 0 ;otherwise
# ```

# %%
from scipy.stats import expon

# %% [markdown]
# Generating the Sample of Size 1000

# %%
expon.rvs( size=100)
# Out:
# array([6.96525772e-01, 1.46756046e+00, 4.00130740e+00, 6.81027406e-02,
#        1.33018762e+00, 5.06546372e-01, 2.79412370e-02, 2.17969604e+00,
#        2.04341154e+00, 4.57113062e-01, 1.40284130e-01, 9.48537281e-01,
#        8.41413956e-01, 2.85274392e+00, 1.19960294e+00, 2.08760565e-01,
#        2.62807406e-01, 2.47579439e-01, 1.85033240e+00, 6.75300455e-01,
#        6.66747293e-01, 1.84016869e+00, 2.83599639e+00, 7.50496988e-01,
#        2.82815652e+00, 9.15262286e-01, 4.32394853e-01, 3.08577484e-01,
#        2.20858927e+00, 9.89763083e-01, 9.85417882e-01, 1.71570062e+00,
#        8.58829666e-01, 3.46794643e-01, 8.15504977e-01, 7.66467765e-01,
#        2.47956545e+00, 5.58408821e-01, 2.42495330e+00, 2.31342233e-01,
#        3.82502909e-01, 1.21942078e-04, 2.86697897e-01, 1.95718902e-01,
#        5.75786535e-01, 2.07704799e+00, 6.61600485e-01, 1.39738947e+00,
#        2.76413454e-02, 3.90126844e-01, 7.49577872e-01, 2.16663826e+00,
# ...

# %% [markdown]
# Find Probability using Probability Mass Function

# %%
expon.pdf(x=30 ,loc = 25 ,scale = 10 )
# Out:
# 0.06065306597126334

# %% [markdown]
# Find Cumulative Distribution Function

# %%
expon.cdf( x=30 ,loc = 25 ,scale = 10 )
# Out:
# 0.3934693402873666

# %% [markdown]
# Moments of Distibution

# %%
m , v , s , k = expon.stats(loc = 25 ,scale = 10 , moments='mvsk')
print("Mean = {} , Variance = {} , Skewness = {} , Kurtosis = {} .".format(m,v,s,k))
# Out:
# Mean = 35.0 , Variance = 100.0 , Skewness = 2.0 , Kurtosis = 6.0 .

# %% [markdown]
# Graph Of Distribution

# %%
plt.figure(figsize=(25,25))
data_01 = expon.rvs( size=100)
plt.hist(data_01, density=True, edgecolor='black')
plt.show()

# %% [markdown]
# #Cauchy Distribution

# %% [markdown]
# The Cauchy distribution is often used in statistics as the canonical example of a "pathological" distribution since both its expected value and its variance are undefined (but see § Explanation of undefined moments below). The Cauchy distribution does not have finite moments of order greater than or equal to one; only fractional absolute moments exist.[1] The Cauchy distribution has no moment generating function.

# %% [markdown]
# A random variable X is said to have a normal distribution with parameter μ (mean) & σ^2(variance) if it's pdf is given by,
# ```
# f( X = x ) = 1/(π(1+x^2)) ; -∞ < x < ∞
#            = 0 ; other wise
# ```

# %%
from scipy.stats import cauchy

# %% [markdown]
# Generating the Sample of Size 1000

# %%
cauchy.rvs(size=100)
# Out:
# array([-7.07803679e-02,  2.89246592e-01, -2.49667793e+00,  9.45059140e-01,
#        -3.32431293e+00, -3.87724484e-01,  1.60237669e+00, -2.13755750e+02,
#        -8.46592259e-01,  7.30355107e-01, -5.74273022e+00, -1.67371792e+00,
#         1.05041601e+00,  3.18801186e+00,  7.61285589e-01, -2.86625240e+00,
#        -1.80356193e-02,  1.22120462e+00, -2.29107312e+00, -1.69540611e+02,
#         3.01070942e-01,  1.57647818e+01,  1.21608115e+00,  1.47592017e+00,
#        -7.96015023e-01, -2.55328623e+00, -1.84757864e+01, -9.02042419e-01,
#        -1.82121968e+00, -2.71186066e-01,  2.32396395e-01, -1.65899509e+00,
#         5.30233175e-01, -1.35746535e-01,  2.04106630e-01,  3.47140561e+01,
#         1.74594737e+00,  1.25162838e+01,  1.25079048e-01, -2.89647096e+00,
#        -4.03663999e+00,  1.18540079e-01,  1.19673202e+00,  2.43769955e-01,
#         3.27123005e-01, -9.56704251e-01,  2.01695722e+00,  5.26566715e-01,
# ...

# %% [markdown]
# Find Probability using Probability Mass Function

# %%
cauchy.pdf(x = 20 , loc  = 25 , scale = 5 )
# Out:
# 0.03183098861837907

# %% [markdown]
# Find Cumulative Distribution Function

# %%
cauchy.cdf(x = 20 , loc  = 25 , scale = 5 )
# Out:
# 0.25

# %% [markdown]
# Moments of Distibution

# %%
m , v , s , k = cauchy.stats(loc  = 25 , scale = 5, moments='mvsk')
print("Mean = {} , Variance = {} , Skewness = {} , Kurtosis = {} .".format(m,v,s,k))
# Out:
# Mean = nan , Variance = nan , Skewness = nan , Kurtosis = nan .

# %% [markdown]
# Graph Of Distribution

# %%
plt.figure(figsize=(25,25))
data_01 =cauchy.rvs(size=100)
plt.hist(data_01, density=True, edgecolor='black')
plt.show()

# %% [markdown]
# #Logistic Distribution

# %% [markdown]
# In probability theory and statistics, the logistic distribution is a continuous probability distribution. Its cumulative distribution function is the logistic function, which appears in logistic regression and feedforward neural networks. It resembles the normal distribution in shape but has heavier tails (higher kurtosis).

# %% [markdown]
# A random variable X is said to have a Logistic distribution with parameter a & b if it's pdf is given by,
# ```
# f(X = x) = [1 + exp {-( x - a ) / b}]^(-1) ; b>0
#          = [1 + tan {(x - a) /2b}] / 2 ; b>0
# ```

# %%
from scipy.stats import logistic

# %% [markdown]
# Generating the Sample of Size 1000

# %%
logistic.rvs(size=100)
# Out:
# array([ 0.08520777,  0.1539989 , -0.0774755 ,  1.49563475, -1.83129803,
#        -2.96647724,  2.00313799, -0.15683475, -1.54946662, -1.3953474 ,
#        -0.54695205, -0.1530379 , -2.77225625,  0.09370857, -0.32861425,
#        -0.73339695, -2.03838053, -1.96231498, -0.36342621, -0.65767224,
#         2.81798485, -2.40452924,  0.02652749,  4.87293017,  1.57515789,
#        -0.80936526,  1.07082899, -0.52761829,  0.57884183, -0.0109702 ,
#        -0.74069838,  0.86142684, -1.1049839 ,  0.81389968,  2.34882178,
#         1.27033019, -0.5467269 ,  0.61560891,  2.92977472,  2.33058389,
#         2.51077531,  0.59640476, -4.57933164,  0.59511241,  0.1652123 ,
#        -0.83563871,  1.58961181,  4.24978875, -1.39707488,  2.8668197 ,
#         0.87866781, -0.24269777,  1.02160921, -0.86727818, -0.45659343,
#        -1.79815962,  0.26353722, -1.49853832,  0.29162299, -0.30016115,
#        -2.31553538, -4.96609265, -1.84696387,  4.70360788, -1.94428511,
# ...

# %% [markdown]
# Find Probability using Probability Mass Function

# %%
logistic.pdf(x = 20 , loc  = 25 , scale = 5 )
# Out:
# 0.03932238664829637

# %% [markdown]
# Find Cumulative Distribution Function

# %%
logistic.cdf(x = 20 , loc  = 25 , scale = 5 )
# Out:
# 0.2689414213699951

# %% [markdown]
# Moments of Distibution

# %%
m , v , s , k = logistic.stats(loc  = 25 , scale = 5, moments='mvsk')
print("Mean = {} , Variance = {} , Skewness = {} , Kurtosis = {} .".format(m,v,s,k))
# Out:
# Mean = 25.0 , Variance = 82.24670334241132 , Skewness = 0.0 , Kurtosis = 1.2 .

# %% [markdown]
# Graph Of Distribution

# %%
plt.figure(figsize=(25,25))
data_01 =logistic.rvs(size=100)
plt.hist(data_01, density=True, edgecolor='black')
plt.show()

# %% [markdown]
# #Laplace Distribution

# %% [markdown]
# The Laplace distribution is a continuous probability distribution named after Pierre-Simon Laplace. It is also sometimes called the double exponential distribution, because it can be thought of as two exponential distributions (with an additional location parameter) spliced together along the abscissa, although the term is also sometimes used to refer to the Gumbel distribution. The difference between two independent identically distributed exponential random variables is governed by a Laplace distribution, as is a Brownian motion evaluated at an exponentially distributed random time. Increments of Laplace motion or a variance gamma process evaluated over the time scale also have a Laplace distribution.

# %% [markdown]
# A random variable X is said to have a standard Laplace distribution if it's pdf is given by,
# ```
# f( X = x ) = exp(-|x|)/2 ; -∞ < x < ∞
#            = 0 ; otherwise
# ```

# %%
from scipy.stats import laplace

# %% [markdown]
# Generating the Sample of Size 1000

# %%
laplace.rvs(loc = 25 ,scale = 10 ,size=100)
# Out:
# array([ 26.60453664,  29.99327472,  16.28500539,  30.90772175,
#         23.99493566,  33.69445338,  -4.85461119,  29.45954778,
#          4.41048634,  15.87675138,  35.60575008,  29.55039722,
#         35.16038779,  43.29566992,  15.82761677,  27.20523348,
#         27.24724509,  10.7301638 ,  11.17936238,  38.21143332,
#         14.16901222,  52.49789185,  33.91720282,  35.16892037,
#         32.4172986 ,  16.12962258,  24.09144817,  23.97437939,
#         21.92894048,  16.36642036,  45.57615326,  34.71422643,
#         25.06831008,  10.85749774,  16.34032158,  25.66582324,
#         29.49644045,  34.76105016,  24.51868129,  28.32396458,
#         45.91004621,  12.31363754,   7.82662339,  23.4419095 ,
#         42.18675464,  28.53039249,  27.05080752,  24.11736862,
#         19.27115351,  25.96660872,  14.38822378,  24.18908987,
#         23.09563975,  27.24113468,  19.73551719,  14.05388202,
#         14.61347369,  20.64112935,  34.08547896,  22.98942428,
# ...

# %% [markdown]
# Find Probability using Probability Mass Function

# %%
laplace.pdf(x = 20 , loc  = 25 , scale = 5 )
# Out:
# 0.036787944117144235

# %% [markdown]
# Find Cumulative Distribution Function

# %%
laplace.cdf(x = 20 , loc  = 25 , scale = 5 )
# Out:
# 0.18393972058572117

# %% [markdown]
# Moments of Distibution

# %%
m , v , s , k = laplace.stats(loc  = 25 , scale = 5, moments='mvsk')
print("Mean = {} , Variance = {} , Skewness = {} , Kurtosis = {} .".format(m,v,s,k))
# Out:
# Mean = 25.0 , Variance = 50.0 , Skewness = 0.0 , Kurtosis = 3.0 .

# %% [markdown]
# Graph Of Distribution

# %%
plt.figure(figsize=(25,25))
data_01 =laplace.rvs(loc = 25 ,scale = 10 ,size=100)
plt.hist(data_01, density=True, edgecolor='black')
plt.show()
